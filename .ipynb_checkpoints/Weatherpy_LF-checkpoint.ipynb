# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %%
#store cities into a dataframe and setting the first column to "City"

cities_df = pd.DataFrame(cities)
cities_df.columns = ["City"]
cities_df.head()
# Out:
#      City
# 0  zatoka
# 1  bethel
# 2  barrow
# 3    aksu
# 4   tiksi

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#creating more empty lists
cities_df["Cloudiness"] = ""
cities_df["Date"] = ""
cities_df["Humidity (%)"] = ""
cities_df["Latitude"] = ""
cities_df["Longitude"] = ""
cities_df["Temperature (F)"] = ""
cities_df["Wind Speed (MPH)"] = ""

cities_df.head()
# Out:
#      City Cloudiness Date Humidity (%) Latitude Longitude Temperature (F)  \
# 0  zatoka
# 1  bethel
# 2  barrow
# 3    aksu
# 4   tiksi
#
#   Wind Speed (MPH)
# 0
# 1
# 2
# 3
# 4

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
count = 0
cities_df["Latitude"] = int()
cities_df["Longitude"] = int()
cities_df["Temperature (F)"] = int()
cities_df["Humidity (%)"]= int()
cities_df["Cloudiness"] = int()
cities_df["Wind Speed (MPH)"] = int()
for index,row in cities_df.iterrows():
    count+= 1
    query_url = url + "appid=" + api_key + "&units=" + units + "&q=" + row['City']
    
    
    try:
        weather_response = requests.get(query_url)
        cityweather = weather_response.json()
        cities_df.set_value(index, "Latitude", (cityweather['coord']['lat']))
        cities_df.set_value(index, "Longitude", (cityweather['coord']['lat']))
        cities_df.set_value(index, "Temperature (F)", (cityweather['main']['temp']))
        cities_df.set_value(index, "Humidity (%)", (cityweather['main']['humidity']))
        cities_df.set_value(index, "Cloudiness", (cityweather['clouds']['all']))
        cities_df.set_value(index, "Wind Speed (MPH)", (cityweather['wind']['speed']))
        
        print("Now retieving city #" + str(count) + "|" + str(row["City"]))
        print(query_url)
          
    except KeyError:
        print("City not found. Skipping...")
        
    continue      
          
print('-------------------------------')
print('Data Processing Complete')
print('-------------------------------')
# Out:
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\12812\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Now retieving city #1|zatoka
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zatoka
# Now retieving city #2|bethel
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bethel
# Now retieving city #3|barrow
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=barrow
# Now retieving city #4|aksu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=aksu
# Now retieving city #5|tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tiksi
# Now retieving city #6|norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=norman wells
# Now retieving city #7|avarua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=avarua
# Now retieving city #8|havelock
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=havelock
# Now retieving city #9|rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=rikitea
# Now retieving city #10|punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=punta arenas
# Now retieving city #11|hilo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hilo
# Now retieving city #12|ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ushuaia
# City not found. Skipping...
# City not found. Skipping...
# Now retieving city #15|samarai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=samarai
# Now retieving city #16|plouzane
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=plouzane
# Now retieving city #17|port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port alfred
# Now retieving city #18|upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=upernavik
# Now retieving city #19|biak
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=biak
# Now retieving city #20|hobart
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hobart
# City not found. Skipping...
# Now retieving city #22|severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=severo-kurilsk
# Now retieving city #23|swan river
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=swan river
# Now retieving city #24|port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port elizabeth
# Now retieving city #25|carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=carnarvon
# Now retieving city #26|cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cidreira
# Now retieving city #27|khurba
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=khurba
# Now retieving city #28|cape town
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cape town
# City not found. Skipping...
# Now retieving city #30|mumford
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mumford
# Now retieving city #31|sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sept-iles
# Now retieving city #32|kalach-na-donu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kalach-na-donu
# Now retieving city #33|cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cabo san lucas
# Now retieving city #34|vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vestmannaeyjar
# Now retieving city #35|bilma
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bilma
# Now retieving city #36|vaini
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vaini
# Now retieving city #37|kiruna
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kiruna
# Now retieving city #38|boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=boa vista
# Now retieving city #39|ulaangom
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ulaangom
# Now retieving city #40|mataura
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mataura
# Now retieving city #41|qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=qaanaaq
# City not found. Skipping...
# Now retieving city #43|saint george
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saint george
# Now retieving city #44|sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sao filipe
# Now retieving city #45|topeka
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=topeka
# City not found. Skipping...
# Now retieving city #47|isangel
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=isangel
# Now retieving city #48|lebu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lebu
# Now retieving city #49|poum
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=poum
# City not found. Skipping...
# Now retieving city #51|manggar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=manggar
# Now retieving city #52|yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yerbogachen
# Now retieving city #53|castro
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=castro
# Now retieving city #54|semey
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=semey
# Now retieving city #55|vardo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vardo
# Now retieving city #56|yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yellowknife
# Now retieving city #57|abonnema
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=abonnema
# Now retieving city #58|komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=komsomolskiy
# Now retieving city #59|hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hermanus
# Now retieving city #60|bluff
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bluff
# Now retieving city #61|nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nikolskoye
# Now retieving city #62|wanxian
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=wanxian
# Now retieving city #63|dikson
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dikson
# Now retieving city #64|abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=abu samrah
# Now retieving city #65|rostovka
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=rostovka
# Now retieving city #66|butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=butaritari
# Now retieving city #67|vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vila velha
# Now retieving city #68|saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saskylakh
# Now retieving city #69|kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kodiak
# Now retieving city #70|zlobin
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zlobin
# Now retieving city #71|port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port lincoln
# Now retieving city #72|dauphin
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dauphin
# Now retieving city #73|likasi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=likasi
# Now retieving city #74|busselton
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=busselton
# Now retieving city #75|belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=belyy yar
# Now retieving city #76|albany
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=albany
# Now retieving city #77|dubbo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dubbo
# Now retieving city #78|khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=khatanga
# Now retieving city #79|jaciara
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=jaciara
# City not found. Skipping...
# Now retieving city #81|jalu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=jalu
# Now retieving city #82|provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=provideniya
# Now retieving city #83|ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ponta do sol
# Now retieving city #84|tibiri
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tibiri
# Now retieving city #85|yaritagua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yaritagua
# Now retieving city #86|puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=puerto ayora
# Now retieving city #87|thompson
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=thompson
# Now retieving city #88|lamar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lamar
# City not found. Skipping...
# Now retieving city #90|zaysan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zaysan
# Now retieving city #91|pecos
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=pecos
# Now retieving city #92|kristiansund
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kristiansund
# Now retieving city #93|geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=geraldton
# Now retieving city #94|puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=puerto leguizamo
# Now retieving city #95|gannan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=gannan
# Now retieving city #96|ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ribeira grande
# Now retieving city #97|vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vila franca do campo
# City not found. Skipping...
# Now retieving city #99|smirnykh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=smirnykh
# City not found. Skipping...
# Now retieving city #101|pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=pangnirtung
# Now retieving city #102|vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vilhena
# Now retieving city #103|mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mar del plata
# Now retieving city #104|vallenar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vallenar
# Now retieving city #105|columbus
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=columbus
# City not found. Skipping...
# Now retieving city #107|cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cockburn town
# Now retieving city #108|chuy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chuy
# City not found. Skipping...
# Now retieving city #110|neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=neuquen
# Now retieving city #111|paragominas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=paragominas
# Now retieving city #112|sangar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sangar
# Now retieving city #113|pisco
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=pisco
# Now retieving city #114|lydenburg
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lydenburg
# Now retieving city #115|badou
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=badou
# Now retieving city #116|lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lerwick
# Now retieving city #117|sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sao joao da barra
# Now retieving city #118|gat
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=gat
# Now retieving city #119|chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chokurdakh
# Now retieving city #120|beloha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=beloha
# City not found. Skipping...
# Now retieving city #122|port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port hardy
# Now retieving city #123|bethanien
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bethanien
# Now retieving city #124|tirumullaivasal
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tirumullaivasal
# Now retieving city #125|zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zhanakorgan
# Now retieving city #126|seoul
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=seoul
# Now retieving city #127|yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yar-sale
# Now retieving city #128|plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=plettenberg bay
# Now retieving city #129|codrington
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=codrington
# Now retieving city #130|rawson
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=rawson
# Now retieving city #131|deep river
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=deep river
# Now retieving city #132|saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saint-philippe
# Now retieving city #133|tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tuktoyaktuk
# Now retieving city #134|chabahar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chabahar
# Now retieving city #135|konotop
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=konotop
# Now retieving city #136|hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hithadhoo
# Now retieving city #137|mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mount gambier
# Now retieving city #138|ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ampanihy
# Now retieving city #139|cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cabedelo
# Now retieving city #140|hofn
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hofn
# Now retieving city #141|alugan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=alugan
# Now retieving city #142|bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bambous virieux
# Now retieving city #143|ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ketchikan
# Now retieving city #144|abeche
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=abeche
# Now retieving city #145|atuona
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=atuona
# Now retieving city #146|pasni
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=pasni
# City not found. Skipping...
# Now retieving city #148|victoria
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=victoria
# Now retieving city #149|mahon
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mahon
# Now retieving city #150|inta
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=inta
# Now retieving city #151|mantua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mantua
# Now retieving city #152|souillac
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=souillac
# Now retieving city #153|uppsala
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=uppsala
# Now retieving city #154|mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mahebourg
# Now retieving city #155|clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=clyde river
# Now retieving city #156|juneau
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=juneau
# Now retieving city #157|kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kapaa
# Now retieving city #158|brezice
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=brezice
# Now retieving city #159|makushino
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=makushino
# Now retieving city #160|petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=petropavlovsk-kamchatskiy
# Now retieving city #161|klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=klaksvik
# Now retieving city #162|sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sobolevo
# Now retieving city #163|canton
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=canton
# Now retieving city #164|takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=takoradi
# Now retieving city #165|diego de almagro
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=diego de almagro
# Now retieving city #166|morondava
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=morondava
# Now retieving city #167|burnie
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=burnie
# City not found. Skipping...
# City not found. Skipping...
# Now retieving city #170|daru
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=daru
# Now retieving city #171|itapirapua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=itapirapua
# Now retieving city #172|luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=luderitz
# Now retieving city #173|korem
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=korem
# Now retieving city #174|laguna
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=laguna
# Now retieving city #175|kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kavieng
# Now retieving city #176|richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=richards bay
# Now retieving city #177|jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=jamestown
# Now retieving city #178|havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=havoysund
# City not found. Skipping...
# Now retieving city #180|igboho
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=igboho
# Now retieving city #181|puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=puerto del rosario
# Now retieving city #182|temecula
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=temecula
# Now retieving city #183|meghri
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=meghri
# Now retieving city #184|sibolga
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sibolga
# Now retieving city #185|gatesville
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=gatesville
# Now retieving city #186|olenegorsk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=olenegorsk
# Now retieving city #187|dicabisagan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dicabisagan
# Now retieving city #188|garliava
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=garliava
# Now retieving city #189|margate
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=margate
# Now retieving city #190|novyy urgal
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=novyy urgal
# Now retieving city #191|labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=labuhan
# Now retieving city #192|airai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=airai
# Now retieving city #193|tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tasiilaq
# Now retieving city #194|talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=talnakh
# Now retieving city #195|wagar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=wagar
# Now retieving city #196|tual
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tual
# Now retieving city #197|vila
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vila
# City not found. Skipping...
# Now retieving city #199|carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=carutapera
# Now retieving city #200|new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=new norfolk
# Now retieving city #201|juba
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=juba
# Now retieving city #202|carbonear
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=carbonear
# Now retieving city #203|chicama
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chicama
# Now retieving city #204|hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hasaki
# City not found. Skipping...
# Now retieving city #206|taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=taoudenni
# Now retieving city #207|mezen
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mezen
# Now retieving city #208|waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=waipawa
# Now retieving city #209|kijang
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kijang
# Now retieving city #210|guipavas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=guipavas
# City not found. Skipping...
# Now retieving city #212|lichinga
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lichinga
# Now retieving city #213|saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saldanha
# Now retieving city #214|eston
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=eston
# Now retieving city #215|haapiti
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=haapiti
# Now retieving city #216|cheshire
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cheshire
# City not found. Skipping...
# Now retieving city #218|doha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=doha
# Now retieving city #219|mackay
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mackay
# City not found. Skipping...
# Now retieving city #221|constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=constitucion
# City not found. Skipping...
# Now retieving city #223|ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ilulissat
# Now retieving city #224|lima
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lima
# Now retieving city #225|huilong
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=huilong
# Now retieving city #226|kushima
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kushima
# Now retieving city #227|savannah bight
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=savannah bight
# Now retieving city #228|severodvinsk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=severodvinsk
# Now retieving city #229|beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=beringovskiy
# Now retieving city #230|sauda
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sauda
# Now retieving city #231|wajir
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=wajir
# Now retieving city #232|nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nanortalik
# City not found. Skipping...
# Now retieving city #234|guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=guerrero negro
# Now retieving city #235|malanje
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=malanje
# Now retieving city #236|torbay
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=torbay
# Now retieving city #237|vao
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vao
# Now retieving city #238|batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=batagay-alyta
# City not found. Skipping...
# Now retieving city #240|barra do garcas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=barra do garcas
# Now retieving city #241|san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=san quintin
# Now retieving city #242|fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=fortuna
# Now retieving city #243|lobito
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lobito
# City not found. Skipping...
# Now retieving city #245|evensk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=evensk
# Now retieving city #246|staroaleyskoye
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=staroaleyskoye
# Now retieving city #247|cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cururupu
# City not found. Skipping...
# Now retieving city #249|oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=oktyabrskoye
# Now retieving city #250|esperance
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=esperance
# Now retieving city #251|cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cherskiy
# Now retieving city #252|helvecia
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=helvecia
# Now retieving city #253|srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=srednekolymsk
# Now retieving city #254|aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=aklavik
# Now retieving city #255|moyale
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=moyale
# Now retieving city #256|qarchi gak
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=qarchi gak
# Now retieving city #257|podgornoye
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=podgornoye
# Now retieving city #258|grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=grand gaube
# Now retieving city #259|berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=berdigestyakh
# Now retieving city #260|sylacauga
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sylacauga
# Now retieving city #261|izacic
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=izacic
# Now retieving city #262|osterburg
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=osterburg
# Now retieving city #263|lamballe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lamballe
# Now retieving city #264|sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sinnamary
# Now retieving city #265|freeport
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=freeport
# Now retieving city #266|cangzhou
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cangzhou
# Now retieving city #267|bushehr
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bushehr
# Now retieving city #268|shubarshi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=shubarshi
# Now retieving city #269|saint pete beach
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saint pete beach
# Now retieving city #270|shingu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=shingu
# Now retieving city #271|mapimi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mapimi
# Now retieving city #272|port blair
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port blair
# Now retieving city #273|georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=georgetown
# Now retieving city #274|lasa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lasa
# Now retieving city #275|zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zhangjiakou
# Now retieving city #276|tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tecoanapa
# Now retieving city #277|chiredzi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chiredzi
# Now retieving city #278|rumford
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=rumford
# Now retieving city #279|general roca
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=general roca
# Now retieving city #280|calmar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=calmar
# Now retieving city #281|kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kununurra
# City not found. Skipping...
# Now retieving city #283|harper
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=harper
# Now retieving city #284|suchedniow
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=suchedniow
# Now retieving city #285|atambua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=atambua
# Now retieving city #286|kushiro
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kushiro
# Now retieving city #287|deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=deputatskiy
# Now retieving city #288|coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=coahuayana
# Now retieving city #289|bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bredasdorp
# Now retieving city #290|ngunguru
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ngunguru
# Now retieving city #291|bo phloi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bo phloi
# Now retieving city #292|sur
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sur
# Now retieving city #293|tezu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tezu
# Now retieving city #294|whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=whitehorse
# Now retieving city #295|kupang
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kupang
# Now retieving city #296|zeitz
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zeitz
# Now retieving city #297|hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hamilton
# Now retieving city #298|yulara
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yulara
# Now retieving city #299|loa janan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=loa janan
# Now retieving city #300|arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=arraial do cabo
# Now retieving city #301|wamba
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=wamba
# Now retieving city #302|sitka
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sitka
# Now retieving city #303|east london
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=east london
# City not found. Skipping...
# Now retieving city #305|eydhafushi
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=eydhafushi
# Now retieving city #306|tosya
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tosya
# Now retieving city #307|nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nemuro
# Now retieving city #308|padang
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=padang
# Now retieving city #309|ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ixtapa
# Now retieving city #310|marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=marrakesh
# Now retieving city #311|adelaide
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=adelaide
# Now retieving city #312|waddan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=waddan
# Now retieving city #313|abu zabad
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=abu zabad
# Now retieving city #314|kayes
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kayes
# Now retieving city #315|sakaiminato
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sakaiminato
# Now retieving city #316|kiama
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kiama
# Now retieving city #317|aquiraz
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=aquiraz
# Now retieving city #318|nome
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nome
# Now retieving city #319|salalah
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=salalah
# Now retieving city #320|cochrane
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cochrane
# Now retieving city #321|san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=san patricio
# Now retieving city #322|bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bosaso
# Now retieving city #323|ndioum
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ndioum
# Now retieving city #324|touros
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=touros
# Now retieving city #325|norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=norfolk
# Now retieving city #326|egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=egvekinot
# Now retieving city #327|ochakiv
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ochakiv
# Now retieving city #328|lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lompoc
# Now retieving city #329|katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=katsuura
# City not found. Skipping...
# Now retieving city #331|zhumadian
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zhumadian
# Now retieving city #332|conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=conceicao do araguaia
# Now retieving city #333|kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kavaratti
# Now retieving city #334|maltahohe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=maltahohe
# City not found. Skipping...
# Now retieving city #336|cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=cayenne
# Now retieving city #337|vostok
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=vostok
# Now retieving city #338|lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lagoa
# Now retieving city #339|mana
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mana
# Now retieving city #340|bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bonthe
# City not found. Skipping...
# Now retieving city #342|oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=oranjemund
# Now retieving city #343|skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=skjervoy
# Now retieving city #344|galle
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=galle
# Now retieving city #345|dingle
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dingle
# Now retieving city #346|miraflores
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=miraflores
# Now retieving city #347|luba
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=luba
# Now retieving city #348|scottsbluff
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=scottsbluff
# Now retieving city #349|dvinskoy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dvinskoy
# ...
# City not found. Skipping...
# City not found. Skipping...
# Now retieving city #472|zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zyryanka
# City not found. Skipping...
# Now retieving city #474|peniche
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=peniche
# Now retieving city #475|arman
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=arman
# Now retieving city #476|mackenzie
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mackenzie
# Now retieving city #477|brownsville
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=brownsville
# Now retieving city #478|selikhino
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=selikhino
# Now retieving city #479|saint-leu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=saint-leu
# Now retieving city #480|mishan
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mishan
# Now retieving city #481|rokytne
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=rokytne
# Now retieving city #482|kota belud
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kota belud
# Now retieving city #483|sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sungaipenuh
# Now retieving city #484|qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=qaqortoq
# Now retieving city #485|hwange
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hwange
# Now retieving city #486|las cruces
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=las cruces
# Now retieving city #487|bhuj
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bhuj
# Now retieving city #488|bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bathsheba
# City not found. Skipping...
# Now retieving city #490|bondo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=bondo
# Now retieving city #491|safranbolu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=safranbolu
# City not found. Skipping...
# Now retieving city #493|algiers
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=algiers
# Now retieving city #494|emerald
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=emerald
# Now retieving city #495|glens falls
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=glens falls
# Now retieving city #496|inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=inuvik
# Now retieving city #497|los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=los llanos de aridane
# Now retieving city #498|yarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yarkovo
# Now retieving city #499|acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=acapulco
# Now retieving city #500|omagh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=omagh
# Now retieving city #501|kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kruisfontein
# Now retieving city #502|kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kalmunai
# Now retieving city #503|yarovoye
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yarovoye
# Now retieving city #504|astoria
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=astoria
# Now retieving city #505|valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=valparaiso
# Now retieving city #506|dolzhanskaya
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=dolzhanskaya
# Now retieving city #507|tucuman
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tucuman
# Now retieving city #508|aitape
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=aitape
# Now retieving city #509|tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tiznit
# Now retieving city #510|santa helena de goias
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=santa helena de goias
# Now retieving city #511|kutum
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kutum
# Now retieving city #512|edd
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=edd
# Now retieving city #513|nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nhulunbuy
# Now retieving city #514|derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=derzhavinsk
# Now retieving city #515|monroe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=monroe
# Now retieving city #516|tahoua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tahoua
# Now retieving city #517|iwanai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=iwanai
# Now retieving city #518|camacha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=camacha
# Now retieving city #519|swan hill
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=swan hill
# Now retieving city #520|malhador
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=malhador
# City not found. Skipping...
# Now retieving city #522|nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nantucket
# Now retieving city #523|olinda
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=olinda
# Now retieving city #524|manyana
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=manyana
# Now retieving city #525|kindu
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kindu
# Now retieving city #526|moscow
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=moscow
# Now retieving city #527|ostashkov
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ostashkov
# Now retieving city #528|gueret
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=gueret
# City not found. Skipping...
# City not found. Skipping...
# Now retieving city #531|kharakvasla
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kharakvasla
# Now retieving city #532|port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=port-cartier
# Now retieving city #533|kuroiso
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kuroiso
# Now retieving city #534|meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=meulaboh
# Now retieving city #535|tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tuatapere
# Now retieving city #536|xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=xai-xai
# Now retieving city #537|botwood
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=botwood
# City not found. Skipping...
# Now retieving city #539|liku
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=liku
# Now retieving city #540|chimbote
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=chimbote
# Now retieving city #541|baherden
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=baherden
# Now retieving city #542|nardaran
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=nardaran
# Now retieving city #543|majengo
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=majengo
# Now retieving city #544|sortland
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=sortland
# Now retieving city #545|colares
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=colares
# Now retieving city #546|wadi maliz
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=wadi maliz
# Now retieving city #547|ambunti
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ambunti
# Now retieving city #548|xining
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=xining
# Now retieving city #549|narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=narsaq
# Now retieving city #550|kovdor
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kovdor
# Now retieving city #551|kailua
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kailua
# Now retieving city #552|juybar
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=juybar
# Now retieving city #553|same
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=same
# Now retieving city #554|turriff
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=turriff
# Now retieving city #555|ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ulladulla
# Now retieving city #556|necochea
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=necochea
# Now retieving city #557|taltal
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=taltal
# Now retieving city #558|kizukuri
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=kizukuri
# Now retieving city #559|ellwangen
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ellwangen
# Now retieving city #560|zhuhai
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=zhuhai
# City not found. Skipping...
# Now retieving city #562|durban
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=durban
# Now retieving city #563|churachandpur
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=churachandpur
# Now retieving city #564|belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=belmonte
# Now retieving city #565|namibe
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=namibe
# Now retieving city #566|westport
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=westport
# Now retieving city #567|yumen
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=yumen
# Now retieving city #568|fort saint james
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=fort saint james
# Now retieving city #569|comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=comodoro rivadavia
# Now retieving city #570|tema
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=tema
# Now retieving city #571|spodnja idrija
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=spodnja idrija
# Now retieving city #572|hay river
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=hay river
# Now retieving city #573|le vauclin
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=le vauclin
# Now retieving city #574|beroroha
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=beroroha
# Now retieving city #575|mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=mehamn
# Now retieving city #576|basoko
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=basoko
# Now retieving city #577|ganzhou
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=ganzhou
# Now retieving city #578|huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=huarmey
# Now retieving city #579|douglas
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=douglas
# Now retieving city #580|linxia
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=linxia
# Now retieving city #581|lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=lorengau
# Now retieving city #582|byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=byron bay
# Now retieving city #583|campoverde
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=campoverde
# Now retieving city #584|turayf
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=turayf
# Now retieving city #585|portland
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=portland
# City not found. Skipping...
# Now retieving city #587|san joaquin
# http://api.openweathermap.org/data/2.5/weather?appid=be81c2ba50ae5566cc5c553e7e338888&units=Imperial&q=san joaquin
# -------------------------------
# Data Processing Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cleaned_df = cities_df.dropna(how="any")
cleaned_df.head()
# Out:
#      City  Cloudiness Date  Humidity (%)  Latitude  Longitude  \
# 0  zatoka          75                 87        50         50
# 1  bethel          40                 65        60         60
# 2  barrow          24                 85       -38        -38
# 3    aksu          90                100        52         52
# 4   tiksi          64                 77        71         71
#
#    Temperature (F)  Wind Speed (MPH)
# 0               43                 2
# 1               43                18
# 2               57                12
# 3               28                 6
# 4                4                 4

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cleaned_df['Latitude'],
           cleaned_df['Temperature (F)'],
           c=cleaned_df["Temperature (F)"],
           edgecolor="black", linewidths=1, marker="o",
           cmap="coolwarm", alpha=0.8, label="City" )
plt.title("Latitude vs. Temperature (F)" + datetime.now().strftime('%Y-%m-%d') + ")")
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Temperature (°F)")
plt.grid(True)
plt.savefig("latitude_vs_temp_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cleaned_df["Latitude"],
           cleaned_df["Humidity (%)"],
           c=cleaned_df["Temperature (F)"],
           edgecolor="black", linewidths=1, marker="o",
           cmap="coolwarm", alpha=0.8, label="City" )
plt.title("Latitude vs. Humidity" + datetime.now().strftime('%Y-%m-%d') + ")")
plt.xlabel("Humidity (%)", fontsize=10)
plt.ylabel("Temperature (°F)")
plt.grid(True)
plt.savefig("humidity_vs_temp_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cleaned_df["Latitude"],
           cleaned_df["Cloudiness"],
           c=cleaned_df["Temperature (F)"],
           edgecolor="black", linewidths=1, marker="o",
           cmap="coolwarm", alpha=0.8, label="City" )
plt.title("Latitude vs. Cloudiness" + datetime.now().strftime('%Y-%m-%d') + ")")
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Cloudiness")
plt.grid(True)
plt.savefig("latitude_vs_cloudiness_scatter_plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cleaned_df["Latitude"],
           cleaned_df["Wind Speed (MPH)"],
           c=cleaned_df["Temperature (F)"],
           edgecolor="black", linewidths=1, marker="o",
           cmap="coolwarm", alpha=0.8, label="City" )
plt.title("Latitude vs. Wind Speed (MPH)" + datetime.now().strftime('%Y-%m-%d') + ")")
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Cloudiness")
plt.grid(True)
plt.savefig("latitude_vs_windspeed_scatter_plot.png")
plt.show()
